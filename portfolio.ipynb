# %% [markdown]
# ## Portfolio 2
#
# In deze portfolio gaan we prompt engineering toepassen om de data van de HBO Kennisbank te webscrapen.
#
# Daarna gaan we met deze data 'een taak' toepassen. Dit gaan we verder finetunen, sampelen, RLAIF en evalueren.

# %% [markdown]
# ## Prompt Engineering
#
# ### Prompt 1
#
# Met deze prompt proberen wij code te genereren om webscraping toe te passen op de HBO Kennisbank website.
#
# In deze prompt maken wij gebruik van .... Deze techniek hebben wij gebruikt, omdat ...

# %%
...

# %% [markdown]
# ### Antwoord

# %%
...

# %%
import pandas as pd

df = pd.read_csv("hbo_kennisbank_full.csv")

# %%
df.head()
# Out:
#                                                title  \
# 0                  Op koers blijven als zijinstromer
# 1  Van Lineaire Ontwerpketens naar Circulaire Ont...
# 2  Understanding shelters as children’s places : ...
# 3  Een betere mentale gezondheid begint niet in d...
# 4  Talentontwikkeling en kansengelijkheid in het ...
#
#                                              authors  \
# 0                           Lectoren en onderzoekers
# 1  Martin Scherpenisse (Onderzoeker); Petra Ronda...
# 2                           Lectoren en onderzoekers
# 3                      Bliekendaal, S. (Onderzoeker)
# 4                           Lectoren en onderzoekers
#
#                                             abstract        year  \
# 0  Op koers blijven als zijinstromer\nkwaliteitsv...  2026-06-10
# 1  Van Lineaire Ontwerpketens naar Circulaire Ont...  2026-04-20
# 2  Understanding shelters as children’s places : ...  2026-05-26
# 3  Een betere mentale gezondheid begint niet in d...  2026-06-24
# 4                 De grootste kennisbank van het HBO  2026-12-31
#
#                                                  url
# 0  https://www.hbo-kennisbank.nl/details/aereshog...
# 1  https://www.hbo-kennisbank.nl/details/sharekit...
# 2  https://www.hbo-kennisbank.nl/details/sharekit...
# 3  https://www.hbo-kennisbank.nl/details/aereshog...
# 4  https://www.hbo-kennisbank.nl/details/hanze_pu...
